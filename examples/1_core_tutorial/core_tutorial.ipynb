# %% [markdown]
# # vowl · Core Tutorial
#
# The main walkthrough of the **vowl** library for validating data against [ODCS](https://github.com/bitol-io/open-data-contract-standard) data contracts. Run it top-to-bottom.
#
# This notebook covers the everyday workflow — setup, running a validation, and understanding the results. Two further notebooks build on it:
#
# - `2_multiple_sources/` — validating one contract across multiple sources
# - `3_real_databases/` — server-side validation with Testcontainers (needs Docker)
#
# ## Contents
#
# 1. [Setup](#1-setup)
# 2. [Auto-Mapped Validation](#2-auto-mapped-validation) — Pandas, Polars, other inputs
# 3. [Explicitly Defined Adapter](#3-explicitly-defined-adapter) — incl. `PooledAdapter`
# 4. [Filtering Rows Before Validation](#4-filtering-rows)
# 5. [The ValidationResult Object](#5-validationresult)
# 6. [Annotated Output — Your Full Table, Flagged](#6-annotated-output)
#
# Generated CSV/JSON artifacts are written to this notebook's local `outputs/` folder.

# %% [markdown]
# <a id="1-setup"></a>
# ## 1. Setup
#
# Install the dependencies (skipped during execution), then resolve the dataset paths used throughout the notebook.

# %%
# Install vowl (skipped during execution)
# %pip install 'vowl[all]'

# %%
from pathlib import Path

# Walk up to the repo root (works no matter how deep this notebook sits)
REPO_ROOT = Path.cwd()
while not (REPO_ROOT / "tests" / "hdb_resale").exists() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent

# Single-source: HDB Resale dataset
HDB_DIR = REPO_ROOT / "tests" / "hdb_resale"
HDB_CSV = HDB_DIR / "HDBResaleWithErrors.csv"
HDB_CONTRACT = HDB_DIR / "hdb_resale_simple.yaml"  # Switch to "hdb_resale.yaml" for a more complex contract

# Multi-source: Employee dataset (payroll + employee list)
EMPLOYEE_DIR = REPO_ROOT / "tests" / "employee"
EMPLOYEE_PAYROLL_CSV = EMPLOYEE_DIR / "demo_employee_payroll.csv"
EMPLOYEE_LIST_CSV = EMPLOYEE_DIR / "demo_employee_list.csv"
EMPLOYEE_CONTRACT = EMPLOYEE_DIR / "employee_payroll_datacontract.yaml"

# Common imports used throughout this notebook
import pandas as pd
from vowl import validate_data

# --- Quieten known, benign warnings emitted by this demo ---
import warnings

# vowl surfaces UserWarnings (Arrow type coercion, multi-schema adapter reuse)
# that are informational for this demo dataset.
warnings.filterwarnings("ignore", category=UserWarning,
                        module=r"vowl\.validation\.runner")

# %%
# Confirm every dataset path resolves
print(f"HDB CSV exists:          {HDB_CSV.exists()}")
print(f"HDB contract exists:     {HDB_CONTRACT.exists()}")
print(f"Employee payroll CSV exists:  {EMPLOYEE_PAYROLL_CSV.exists()}")
print(f"Employee list CSV exists: {EMPLOYEE_LIST_CSV.exists()}")
print(f"Employee contract exists:     {EMPLOYEE_CONTRACT.exists()}")
# Out:
# HDB CSV exists:          True
# HDB contract exists:     True
# Employee payroll CSV exists:  True
# Employee list CSV exists: True
# Employee contract exists:     True

# %% [markdown]
# ---
#
# # Running a Validation
#
# The ways to feed your data into vowl: let it auto-detect the input type, hand it an explicit adapter, or filter the rows before validating.

# %% [markdown]
# <a id="2-auto-mapped-validation"></a>
# ## 2. Auto-Mapped Validation
#
# When you pass a DataFrame directly to `validate_data(df=...)`, vowl uses a `DataSourceMapper` to automatically detect the input type (pandas, Polars, PyArrow, cuDF, Modin, etc.) and route it to the appropriate adapter -- in most cases, an in-memory DuckDB connection via `IbisAdapter`.
#
# This is the simplest way to validate data. For explicit control over the adapter, see [Section 3](#3-explicitly-defined-adapter).
#
# ### 2.1 Pandas

# %%
import pandas as pd
from vowl import validate_data

df = pd.read_csv(HDB_CSV, low_memory=False).fillna("")

# %%
# Inspect the loaded data
print(f"Loaded {len(df)} rows, {len(df.columns)} columns")
df.head()
# Out:
# Loaded 201879 rows, 11 columns
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model lease_commence_date     remaining_lease  \
# 0            44.0        Improved                1979  61 years 04 months
# 1            67.0  New Generation                1978  60 years 07 months
# 2            67.0  New Generation                1980  62 years 05 months
# 3            68.0  New Generation                1980   62 years 01 month
# 4            67.0  New Generation                1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %%
result = validate_data(contract=str(HDB_CONTRACT), df=df)

# %%
# Show the full validation report
result.display_full_report()
# Out:
# === Data Quality Validation Results ===
#    Contract Version:      v3.1.0
#    Contract ID:           c11443ee-542f-4442-b28d-2d224342be37
#    Schemas:               hdb_resale_prices
#
#  OVERALL DATA QUALITY
#    Overall:
#      Checks Pass Rate:       16 / 20 (80.0%)
#
#    hdb_resale_prices:
#      Overall:
#        Checks Pass Rate:       16 / 20 (80.0%)
#        ERRORED Checks:         0
#      Single Table:
#        Checks Pass Rate:       16 / 20 (80.0%)
#        ERRORED Checks:         0
#        Unique Passed Rows:     201,861 / 201,879 (99.9%)
#      Multi Table:
#        Checks Pass Rate:       0 / 0 (N/A)
#        ERRORED Checks:         0
#        Non-unique Failed Rows: 0
#
#
#  CHECK RESULTS
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | check_id                                | Target                                | tables_in_query   | status | operator      | expected      | actual | execution time |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | AddressBlockHouseNumber                 | hdb_resale_prices.block               | hdb_resale_prices | FAILED | mustBe        | 0             | 1      | 17.99 ms       |
# | Month                                   | hdb_resale_prices.month               | hdb_resale_prices | FAILED | mustBe        | 0             | 2      | 20.73 ms       |
# | Year                                    | hdb_resale_prices.lease_commence_date | hdb_resale_prices | FAILED | mustBe        | 0             | 3      | 17.34 ms       |
# | floor_area_must_be_less_than_200        | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | FAILED | mustBe        | 0             | 12     | 14.77 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | block_column_exists_check               | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.13 ms        |
# | flat_model_column_exists_check          | hdb_resale_prices.flat_model          | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.18 ms        |
# | flat_type_column_exists_check           | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.90 ms        |
# | flat_type_invalidValues                 | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 18.74 ms       |
# | floor_area_sqm_column_exists_check      | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.45 ms        |
# | hdb_resale_prices_rowCount              | hdb_resale_prices                     | hdb_resale_prices | PASSED | mustBeBetween | [0, 30000000] | 201879 | 6.67 ms        |
# | lease_commence_date_column_exists_check | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.78 ms        |
# | month_column_exists_check               | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.39 ms        |
# | month_logical_type_check                | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 7.45 ms        |
# | remaining_lease_column_exists_check     | hdb_resale_prices.remaining_lease     | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.82 ms        |
# | resale_price_column_exists_check        | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.61 ms        |
# | resale_price_must_not_exceed_2m         | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 14.17 ms       |
# | storey_range_column_exists_check        | hdb_resale_prices.storey_range        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.00 ms        |
# | street_name_column_exists_check         | hdb_resale_prices.street_name         | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.27 ms        |
# | town_column_exists_check                | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.04 ms        |
# | town_nullValues                         | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 13.78 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# Total Execution:       178.20 ms
#
# === Failed Checks and Rows (up to 5 row(s) per failed check) ===
#
#   hdb_resale_prices
#     Single checks
#
#       [Month]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     2
#         Target:   hdb_resale_prices.month
#         Details:  Based on ISO 8601, assumed to be in UTC +8 | YYYY-MM
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE NOT REGEXP_MATCHES(TRY_CAST(month AS TEXT), '^[0-9]{4}-(0[1-9]|1[0-2])$')
#         Rows shown: 2 of 2
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
# | month    | town   | flat_type | block | street_name  | storey_range | floor_area_sqm | flat_model    | lease_commence_date | remaining_lease    | resale_price |
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
# | 2017-jan | BEDOK  | 5 ROOM    | 21    | CHAI CHEE RD | 07 TO 09     | 130.0          | Adjoined flat | 1972                | 54 years 06 months | 530000.0     |
# | 2017-jan | BISHAN | 3 ROOM    | 105   | BISHAN ST 12 | 04 TO 06     | 4.0            | Simplified    | 1985                | 67 years 11 months | 395000.0     |
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
#
#       [AddressBlockHouseNumber]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     1
#         Target:   hdb_resale_prices.block
#         Details:  House number component of a street address | Alphanumeric up to 10 characters (e.g. 12, 535, 358C)
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE NOT REGEXP_MATCHES(TRY_CAST(block AS TEXT), '^[A-Za-z0-9]{1,10}$')
#         Rows shown: 1 of 1
# +---------+-------+-----------+-------+--------------------+--------------+----------------+------------+---------------------+--------------------+--------------+
# | month   | town  | flat_type | block | street_name        | storey_range | floor_area_sqm | flat_model | lease_commence_date | remaining_lease    | resale_price |
# +---------+-------+-----------+-------+--------------------+--------------+----------------+------------+---------------------+--------------------+--------------+
# | 2017-01 | BEDOK | 4 ROOM    |       | BEDOK RESERVOIR RD | 07 TO 09     | 84.0           | Simplified | 1986                | 68 years 10 months | 395000.0     |
# +---------+-------+-----------+-------+--------------------+--------------+----------------+------------+---------------------+--------------------+--------------+
#
#       [floor_area_must_be_less_than_200]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     12
#         Target:   hdb_resale_prices.floor_area_sqm
#         Details:  Validates that floor area must be less than 200
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE TRY_CAST(floor_area_sqm AS BIGINT) >= 200
#         Rows shown: 5 of 12
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
# | month   | town            | flat_type | block | street_name         | storey_range | floor_area_sqm | flat_model         | lease_commence_date | remaining_lease    | resale_price |
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
# | 2017-06 | KALLANG/WHAMPOA | 3 ROOM    | 38    | JLN BAHAGIA         | 01 TO 03     | 215.0          | Terrace            | 1972                | 54 years 01 month  | 830000.0     |
# | 2017-09 | CHOA CHU KANG   | EXECUTIVE | 641   | CHOA CHU KANG ST 64 | 16 TO 18     | 215.0          | Premium Maisonette | 1998                | 79 years 04 months | 888000.0     |
# | 2017-12 | KALLANG/WHAMPOA | 3 ROOM    | 65    | JLN MA'MOR          | 01 TO 03     | 249.0          | Terrace            | 1972                | 53 years 07 months | 1053888.0    |
# | 2018-01 | CHOA CHU KANG   | EXECUTIVE | 639   | CHOA CHU KANG ST 64 | 10 TO 12     | 215.0          | Premium Maisonette | 1998                | 79 years           | 900000.0     |
# | 2018-09 | KALLANG/WHAMPOA | 3 ROOM    | 41    | JLN BAHAGIA         | 01 TO 03     | 237.0          | Terrace            | 1972                | 52 years 10 months | 1185000.0    |
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
#
#       [Year]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     3
#         Target:   hdb_resale_prices.lease_commence_date
#         Details:  Based on ISO 8601, assumed to be in UTC +8 | YYYY
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE NOT REGEXP_MATCHES(TRY_CAST(lease_commence_date AS TEXT), '^[0-9]{4}$')
#         Rows shown: 3 of 3
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# | month   | town       | flat_type | block | street_name      | storey_range | floor_area_sqm | flat_model     | lease_commence_date | remaining_lease    | resale_price |
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# | 2017-01 | ANG MO KIO | 3 ROOM    | 219   | ANG MO KIO AVE 1 | 07 TO 09     | 67.0           | New Generation | 1977.0              | 59 years 06 months | 297000.0     |
# | 2017-01 | ANG MO KIO | 3 ROOM    | 211   | ANG MO KIO AVE 3 | 01 TO 03     | 67.0           | New Generation | abc                 | 59 years 03 months | 325000.0     |
# | 2017-01 | ANG MO KIO | 3 ROOM    | 330   | ANG MO KIO AVE 1 | 07 TO 09     | 68.0           | New Generation |                     | 63 years           | 338000.0     |
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# ValidationResult(passed=False, checks=20, passed_checks=16, failed_checks=4)

# %% [markdown]
# <a id="22-polars"></a>
# ### 2.2 Polars
#
# vowl works with any [Narwhals-compatible](https://github.com/narwhals-dev/narwhals) DataFrame. Here we use Polars with the same contract.

# %%
import polars as pl

polars_df = pl.read_csv(HDB_CSV, infer_schema_length=9999999) # To allow mixed type data to be detected in this demo example
result = validate_data(contract=str(HDB_CONTRACT), df=polars_df)

# %%
print(f"Loaded {len(polars_df)} rows via Polars")
result.display_full_report()
# Out:
# Loaded 201879 rows via Polars
#
#
# === Data Quality Validation Results ===
#    Contract Version:      v3.1.0
#    Contract ID:           c11443ee-542f-4442-b28d-2d224342be37
#    Schemas:               hdb_resale_prices
#
#  OVERALL DATA QUALITY
#    Overall:
#      Checks Pass Rate:       17 / 20 (85.0%)
#
#    hdb_resale_prices:
#      Overall:
#        Checks Pass Rate:       17 / 20 (85.0%)
#        ERRORED Checks:         0
#      Single Table:
#        Checks Pass Rate:       17 / 20 (85.0%)
#        ERRORED Checks:         0
#        Unique Passed Rows:     201,863 / 201,879 (99.9%)
#      Multi Table:
#        Checks Pass Rate:       0 / 0 (N/A)
#        ERRORED Checks:         0
#        Non-unique Failed Rows: 0
#
#
#  CHECK RESULTS
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | check_id                                | Target                                | tables_in_query   | status | operator      | expected      | actual | execution time |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | Month                                   | hdb_resale_prices.month               | hdb_resale_prices | FAILED | mustBe        | 0             | 2      | 18.34 ms       |
# | Year                                    | hdb_resale_prices.lease_commence_date | hdb_resale_prices | FAILED | mustBe        | 0             | 2      | 20.30 ms       |
# | floor_area_must_be_less_than_200        | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | FAILED | mustBe        | 0             | 12     | 16.94 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | AddressBlockHouseNumber                 | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 19.48 ms       |
# | block_column_exists_check               | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.12 ms        |
# | flat_model_column_exists_check          | hdb_resale_prices.flat_model          | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.55 ms        |
# | flat_type_column_exists_check           | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.98 ms        |
# | flat_type_invalidValues                 | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 23.14 ms       |
# | floor_area_sqm_column_exists_check      | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.97 ms        |
# | hdb_resale_prices_rowCount              | hdb_resale_prices                     | hdb_resale_prices | PASSED | mustBeBetween | [0, 30000000] | 201879 | 6.56 ms        |
# | lease_commence_date_column_exists_check | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.33 ms        |
# | month_column_exists_check               | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.17 ms        |
# | month_logical_type_check                | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 25.43 ms       |
# | remaining_lease_column_exists_check     | hdb_resale_prices.remaining_lease     | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.02 ms        |
# | resale_price_column_exists_check        | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.98 ms        |
# | resale_price_must_not_exceed_2m         | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 17.40 ms       |
# | storey_range_column_exists_check        | hdb_resale_prices.storey_range        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.14 ms        |
# | street_name_column_exists_check         | hdb_resale_prices.street_name         | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.97 ms        |
# | town_column_exists_check                | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.99 ms        |
# | town_nullValues                         | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 11.99 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# Total Execution:       207.80 ms
#
# === Failed Checks and Rows (up to 5 row(s) per failed check) ===
#
#   hdb_resale_prices
#     Single checks
#
#       [Month]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     2
#         Target:   hdb_resale_prices.month
#         Details:  Based on ISO 8601, assumed to be in UTC +8 | YYYY-MM
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE NOT REGEXP_MATCHES(TRY_CAST(month AS TEXT), '^[0-9]{4}-(0[1-9]|1[0-2])$')
#         Rows shown: 2 of 2
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
# | month    | town   | flat_type | block | street_name  | storey_range | floor_area_sqm | flat_model    | lease_commence_date | remaining_lease    | resale_price |
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
# | 2017-jan | BEDOK  | 5 ROOM    | 21    | CHAI CHEE RD | 07 TO 09     | 130.0          | Adjoined flat | 1972                | 54 years 06 months | 530000.0     |
# | 2017-jan | BISHAN | 3 ROOM    | 105   | BISHAN ST 12 | 04 TO 06     | 4.0            | Simplified    | 1985                | 67 years 11 months | 395000.0     |
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
#
#       [floor_area_must_be_less_than_200]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     12
#         Target:   hdb_resale_prices.floor_area_sqm
#         Details:  Validates that floor area must be less than 200
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE TRY_CAST(floor_area_sqm AS BIGINT) >= 200
#         Rows shown: 5 of 12
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
# | month   | town            | flat_type | block | street_name         | storey_range | floor_area_sqm | flat_model         | lease_commence_date | remaining_lease    | resale_price |
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
# | 2017-06 | KALLANG/WHAMPOA | 3 ROOM    | 38    | JLN BAHAGIA         | 01 TO 03     | 215.0          | Terrace            | 1972                | 54 years 01 month  | 830000.0     |
# | 2017-09 | CHOA CHU KANG   | EXECUTIVE | 641   | CHOA CHU KANG ST 64 | 16 TO 18     | 215.0          | Premium Maisonette | 1998                | 79 years 04 months | 888000.0     |
# | 2017-12 | KALLANG/WHAMPOA | 3 ROOM    | 65    | JLN MA'MOR          | 01 TO 03     | 249.0          | Terrace            | 1972                | 53 years 07 months | 1053888.0    |
# | 2018-01 | CHOA CHU KANG   | EXECUTIVE | 639   | CHOA CHU KANG ST 64 | 10 TO 12     | 215.0          | Premium Maisonette | 1998                | 79 years           | 900000.0     |
# | 2018-09 | KALLANG/WHAMPOA | 3 ROOM    | 41    | JLN BAHAGIA         | 01 TO 03     | 237.0          | Terrace            | 1972                | 52 years 10 months | 1185000.0    |
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
#
#       [Year]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     2
#         Target:   hdb_resale_prices.lease_commence_date
#         Details:  Based on ISO 8601, assumed to be in UTC +8 | YYYY
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE NOT REGEXP_MATCHES(TRY_CAST(lease_commence_date AS TEXT), '^[0-9]{4}$')
#         Rows shown: 2 of 2
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# | month   | town       | flat_type | block | street_name      | storey_range | floor_area_sqm | flat_model     | lease_commence_date | remaining_lease    | resale_price |
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# | 2017-01 | ANG MO KIO | 3 ROOM    | 219   | ANG MO KIO AVE 1 | 07 TO 09     | 67.0           | New Generation | 1977.0              | 59 years 06 months | 297000.0     |
# | 2017-01 | ANG MO KIO | 3 ROOM    | 211   | ANG MO KIO AVE 3 | 01 TO 03     | 67.0           | New Generation | abc                 | 59 years 03 months | 325000.0     |
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# ValidationResult(passed=False, checks=20, passed_checks=17, failed_checks=3)

# %% [markdown]
# #### Why Do Pandas and Polars Show Different Failure Counts?
#
# Pandas reports **4 failed checks** (16/20 pass) while Polars reports **3 failed checks** (17/20 pass). The differences stem from how each library handles null/empty values before they reach DuckDB:
#
# | Check | Pandas | Polars | Reason |
# |-------|--------|--------|--------|
# | **AddressBlockHouseNumber** | FAILED (1 row) | PASSED | Pandas `fillna("")` converts a null `block` to an empty string `""`, which fails the regex `^[A-Za-z0-9]{1,10}$`. Polars keeps it as `null`, and SQL `WHERE ... !~ pattern` evaluates to `NULL` (not `TRUE`), so the row is not counted. |
# | **Year** | FAILED (3 rows) | FAILED (2 rows) | One record has an empty `lease_commence_date`. In Pandas, `fillna("")` turns it into `""` which fails the `^[0-9]{4}$` regex. In Polars, the value stays `null` and is skipped by the WHERE clause. |
#
# This is a documented aspect of null handling across backends -- see [Known Issues: Null Handling](../../docs/known-issues.md#null-handling-varies-across-database-backends). If you need to catch nulls explicitly, add a `nullValues` library check to your contract.

# %% [markdown]
# ### 2.3 Other Inputs (Connection Strings, Ibis Backends, Spark, Arrow)
#
# The auto-mapper accepts more than DataFrames. vowl detects the type and creates the appropriate `IbisAdapter` automatically.

# %%
# The auto-mapper supports more than just DataFrames.
# Below are other input types that validate_data() can auto-detect:

# --- Connection string (any URI that Ibis recognises) ---
# result = validate_data(contract=str(HDB_CONTRACT), df="postgresql://<user>:<password>@<host>:<port>/<dbname>")
# result = validate_data(contract=str(HDB_CONTRACT), df="snowflake://<user>:<password>@<account>/<db>/<schema>")

# --- Ibis backend (already connected) ---
# con = ibis.duckdb.connect("my_database.ddb")
# result = validate_data(contract=str(HDB_CONTRACT), df=con)

# --- PySpark DataFrame ---
# spark_df = spark.read.table("my_table")
# result = validate_data(contract=str(HDB_CONTRACT), df=spark_df)

# --- PyArrow Table ---
# import pyarrow.csv as pcsv
# arrow_table = pcsv.read_csv("data.csv")
# result = validate_data(contract=str(HDB_CONTRACT), df=arrow_table)

# %% [markdown]
# <a id="3-explicitly-defined-adapter"></a>
# ## 3. Explicitly Defined Adapter
#
# Instead of relying on auto-mapping (Section 2), you can explicitly create an `IbisAdapter` and pass it to `validate_data(adapter=...)`. This gives you full control over the connection, backend, and configuration.
#
# Here we use DuckDB in-memory by materialising the table before validating. The SQL checks run **client-side** within the DuckDB process. This same pattern works with any of the [20+ Ibis backends](https://github.com/ibis-project/ibis) (PostgreSQL, Snowflake, BigQuery, etc.).

# %%
import ibis
from vowl import validate_data
from vowl.adapters import IbisAdapter

# Create an in-memory DuckDB connection and register the data
con = ibis.duckdb.connect()
hdb_df = pd.read_csv(HDB_CSV, low_memory=False).fillna("")
hdb_df["lease_commence_date"] = hdb_df["lease_commence_date"].astype(str)
con.create_table("hdb_resale_prices", hdb_df)

# Validate using the IbisAdapter. SQL checks run client-side in DuckDB
adapter = IbisAdapter(con)
result = validate_data(contract=str(HDB_CONTRACT), adapter=adapter)

# %%
# Show the full validation report
result.display_full_report()
# Out:
# === Data Quality Validation Results ===
#    Contract Version:      v3.1.0
#    Contract ID:           c11443ee-542f-4442-b28d-2d224342be37
#    Schemas:               hdb_resale_prices
#
#  OVERALL DATA QUALITY
#    Overall:
#      Checks Pass Rate:       16 / 20 (80.0%)
#
#    hdb_resale_prices:
#      Overall:
#        Checks Pass Rate:       16 / 20 (80.0%)
#        ERRORED Checks:         0
#      Single Table:
#        Checks Pass Rate:       16 / 20 (80.0%)
#        ERRORED Checks:         0
#        Unique Passed Rows:     201,861 / 201,879 (99.9%)
#      Multi Table:
#        Checks Pass Rate:       0 / 0 (N/A)
#        ERRORED Checks:         0
#        Non-unique Failed Rows: 0
#
#
#  CHECK RESULTS
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | check_id                                | Target                                | tables_in_query   | status | operator      | expected      | actual | execution time |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | AddressBlockHouseNumber                 | hdb_resale_prices.block               | hdb_resale_prices | FAILED | mustBe        | 0             | 1      | 20.43 ms       |
# | Month                                   | hdb_resale_prices.month               | hdb_resale_prices | FAILED | mustBe        | 0             | 2      | 19.80 ms       |
# | Year                                    | hdb_resale_prices.lease_commence_date | hdb_resale_prices | FAILED | mustBe        | 0             | 3      | 21.26 ms       |
# | floor_area_must_be_less_than_200        | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | FAILED | mustBe        | 0             | 12     | 17.85 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | block_column_exists_check               | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.76 ms        |
# | flat_model_column_exists_check          | hdb_resale_prices.flat_model          | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.69 ms        |
# | flat_type_column_exists_check           | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.69 ms        |
# | flat_type_invalidValues                 | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 21.39 ms       |
# | floor_area_sqm_column_exists_check      | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.05 ms        |
# | hdb_resale_prices_rowCount              | hdb_resale_prices                     | hdb_resale_prices | PASSED | mustBeBetween | [0, 30000000] | 201879 | 7.86 ms        |
# | lease_commence_date_column_exists_check | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.57 ms        |
# | month_column_exists_check               | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.06 ms        |
# | month_logical_type_check                | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.91 ms        |
# | remaining_lease_column_exists_check     | hdb_resale_prices.remaining_lease     | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.80 ms        |
# | resale_price_column_exists_check        | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.93 ms        |
# | resale_price_must_not_exceed_2m         | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 14.58 ms       |
# | storey_range_column_exists_check        | hdb_resale_prices.storey_range        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.09 ms        |
# | street_name_column_exists_check         | hdb_resale_prices.street_name         | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.66 ms        |
# | town_column_exists_check                | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.89 ms        |
# | town_nullValues                         | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 13.48 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# Total Execution:       185.75 ms
#
# === Failed Checks and Rows (up to 5 row(s) per failed check) ===
#
#   hdb_resale_prices
#     Single checks
#
#       [Month]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     2
#         Target:   hdb_resale_prices.month
#         Details:  Based on ISO 8601, assumed to be in UTC +8 | YYYY-MM
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE NOT REGEXP_MATCHES(TRY_CAST(month AS TEXT), '^[0-9]{4}-(0[1-9]|1[0-2])$')
#         Rows shown: 2 of 2
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
# | month    | town   | flat_type | block | street_name  | storey_range | floor_area_sqm | flat_model    | lease_commence_date | remaining_lease    | resale_price |
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
# | 2017-jan | BEDOK  | 5 ROOM    | 21    | CHAI CHEE RD | 07 TO 09     | 130.0          | Adjoined flat | 1972                | 54 years 06 months | 530000.0     |
# | 2017-jan | BISHAN | 3 ROOM    | 105   | BISHAN ST 12 | 04 TO 06     | 4.0            | Simplified    | 1985                | 67 years 11 months | 395000.0     |
# +----------+--------+-----------+-------+--------------+--------------+----------------+---------------+---------------------+--------------------+--------------+
#
#       [AddressBlockHouseNumber]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     1
#         Target:   hdb_resale_prices.block
#         Details:  House number component of a street address | Alphanumeric up to 10 characters (e.g. 12, 535, 358C)
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE NOT REGEXP_MATCHES(TRY_CAST(block AS TEXT), '^[A-Za-z0-9]{1,10}$')
#         Rows shown: 1 of 1
# +---------+-------+-----------+-------+--------------------+--------------+----------------+------------+---------------------+--------------------+--------------+
# | month   | town  | flat_type | block | street_name        | storey_range | floor_area_sqm | flat_model | lease_commence_date | remaining_lease    | resale_price |
# +---------+-------+-----------+-------+--------------------+--------------+----------------+------------+---------------------+--------------------+--------------+
# | 2017-01 | BEDOK | 4 ROOM    |       | BEDOK RESERVOIR RD | 07 TO 09     | 84.0           | Simplified | 1986                | 68 years 10 months | 395000.0     |
# +---------+-------+-----------+-------+--------------------+--------------+----------------+------------+---------------------+--------------------+--------------+
#
#       [floor_area_must_be_less_than_200]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     12
#         Target:   hdb_resale_prices.floor_area_sqm
#         Details:  Validates that floor area must be less than 200
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE TRY_CAST(floor_area_sqm AS BIGINT) >= 200
#         Rows shown: 5 of 12
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
# | month   | town            | flat_type | block | street_name         | storey_range | floor_area_sqm | flat_model         | lease_commence_date | remaining_lease    | resale_price |
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
# | 2017-06 | KALLANG/WHAMPOA | 3 ROOM    | 38    | JLN BAHAGIA         | 01 TO 03     | 215.0          | Terrace            | 1972                | 54 years 01 month  | 830000.0     |
# | 2017-09 | CHOA CHU KANG   | EXECUTIVE | 641   | CHOA CHU KANG ST 64 | 16 TO 18     | 215.0          | Premium Maisonette | 1998                | 79 years 04 months | 888000.0     |
# | 2017-12 | KALLANG/WHAMPOA | 3 ROOM    | 65    | JLN MA'MOR          | 01 TO 03     | 249.0          | Terrace            | 1972                | 53 years 07 months | 1053888.0    |
# | 2018-01 | CHOA CHU KANG   | EXECUTIVE | 639   | CHOA CHU KANG ST 64 | 10 TO 12     | 215.0          | Premium Maisonette | 1998                | 79 years           | 900000.0     |
# | 2018-09 | KALLANG/WHAMPOA | 3 ROOM    | 41    | JLN BAHAGIA         | 01 TO 03     | 237.0          | Terrace            | 1972                | 52 years 10 months | 1185000.0    |
# +---------+-----------------+-----------+-------+---------------------+--------------+----------------+--------------------+---------------------+--------------------+--------------+
#
#       [Year]
#         Operator:   mustBe
#         Expected:   0
#         Actual:     3
#         Target:   hdb_resale_prices.lease_commence_date
#         Details:  Based on ISO 8601, assumed to be in UTC +8 | YYYY
#         Rule:     SELECT COUNT(*) FROM "hdb_resale_prices" WHERE NOT REGEXP_MATCHES(TRY_CAST(lease_commence_date AS TEXT), '^[0-9]{4}$')
#         Rows shown: 3 of 3
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# | month   | town       | flat_type | block | street_name      | storey_range | floor_area_sqm | flat_model     | lease_commence_date | remaining_lease    | resale_price |
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# | 2017-01 | ANG MO KIO | 3 ROOM    | 219   | ANG MO KIO AVE 1 | 07 TO 09     | 67.0           | New Generation | 1977.0              | 59 years 06 months | 297000.0     |
# | 2017-01 | ANG MO KIO | 3 ROOM    | 211   | ANG MO KIO AVE 3 | 01 TO 03     | 67.0           | New Generation | abc                 | 59 years 03 months | 325000.0     |
# | 2017-01 | ANG MO KIO | 3 ROOM    | 330   | ANG MO KIO AVE 1 | 07 TO 09     | 68.0           | New Generation |                     | 63 years           | 338000.0     |
# +---------+------------+-----------+-------+------------------+--------------+----------------+----------------+---------------------+--------------------+--------------+
# ValidationResult(passed=False, checks=20, passed_checks=16, failed_checks=4)

# %% [markdown]
# <a id="35-pooled-adapter"></a>
# ### 3.1 Running Checks Concurrently with `PooledAdapter`
#
# By default an adapter runs each check sequentially on a single connection. When a contract has many independent checks and the backend can serve several queries at once, you can run them **concurrently** by wrapping a connection *factory* in a `PooledAdapter`.
#
# `PooledAdapter` keeps a thread-safe pool of adapter instances (one connection per worker, each used by at most one thread at a time) and dispatches checks across them. You give it:
#
# - `factory` — a zero-argument callable that returns a fresh `BaseAdapter` (e.g. an `IbisAdapter` over a new connection). It is called once per pooled connection, so any table the contract references must be available on every connection the factory builds.
# - `max_concurrency` — the maximum number of connections (and therefore in-flight checks) to use.
#
# Because `PooledAdapter` is a connection pool rather than a single Ibis connection, it is wired in through a `MultiSourceAdapter` (the same entry point used for multi-source validation in the [Multiple Sources notebook](../2_multiple_sources/multiple_sources.ipynb)) and passed via `validate_data(adapters=...)`. The verdicts are identical to a sequential run — pooling only changes how the checks are scheduled, not their results.

# %%
from vowl.adapters import PooledAdapter, MultiSourceAdapter

# A factory that builds a *fresh* adapter (new connection) on each call.
# The pool calls it once per worker, so the table must be registered on
# every connection it creates -- hence we load the CSV inside the factory.
def make_duckdb_adapter():
    con = ibis.duckdb.connect()
    df = pd.read_csv(HDB_CSV, low_memory=False).fillna("")
    df["lease_commence_date"] = df["lease_commence_date"].astype(str)
    con.create_table("hdb_resale_prices", df)
    return IbisAdapter(con)

# Wrap the factory in a pool, then route it through a MultiSourceAdapter
# keyed by the schema name the contract validates.
pooled = PooledAdapter(factory=make_duckdb_adapter, max_concurrency=4)
multi = MultiSourceAdapter({"hdb_resale_prices": pooled})

result = validate_data(contract=str(HDB_CONTRACT), adapters=multi)

print(f"Ran {result.summary['validation_summary']['total_checks']} checks "
      f"across up to {pooled.max_concurrency} concurrent connections.")
# Out:
# Ran 20 checks across up to 4 concurrent connections.

# %%
# Same ValidationResult as a sequential run -- just scheduled concurrently
result.print_summary()
# Out:
# === Data Quality Validation Results ===
#    Contract Version:      v3.1.0
#    Contract ID:           c11443ee-542f-4442-b28d-2d224342be37
#    Schemas:               hdb_resale_prices
#
#  OVERALL DATA QUALITY
#    Overall:
#      Checks Pass Rate:       16 / 20 (80.0%)
#
#    hdb_resale_prices:
#      Overall:
#        Checks Pass Rate:       16 / 20 (80.0%)
#        ERRORED Checks:         0
#      Single Table:
#        Checks Pass Rate:       16 / 20 (80.0%)
#        ERRORED Checks:         0
#        Unique Passed Rows:     201,861 / 201,879 (99.9%)
#      Multi Table:
#        Checks Pass Rate:       0 / 0 (N/A)
#        ERRORED Checks:         0
#        Non-unique Failed Rows: 0
#
#
#  CHECK RESULTS
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | check_id                                | Target                                | tables_in_query   | status | operator      | expected      | actual | execution time |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | AddressBlockHouseNumber                 | hdb_resale_prices.block               | hdb_resale_prices | FAILED | mustBe        | 0             | 1      | 21.18 ms       |
# | Month                                   | hdb_resale_prices.month               | hdb_resale_prices | FAILED | mustBe        | 0             | 2      | 20.56 ms       |
# | Year                                    | hdb_resale_prices.lease_commence_date | hdb_resale_prices | FAILED | mustBe        | 0             | 3      | 29.86 ms       |
# | floor_area_must_be_less_than_200        | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | FAILED | mustBe        | 0             | 12     | 18.22 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | block_column_exists_check               | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.74 ms        |
# | flat_model_column_exists_check          | hdb_resale_prices.flat_model          | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.74 ms        |
# | flat_type_column_exists_check           | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.80 ms        |
# | flat_type_invalidValues                 | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 21.02 ms       |
# | floor_area_sqm_column_exists_check      | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.84 ms        |
# | hdb_resale_prices_rowCount              | hdb_resale_prices                     | hdb_resale_prices | PASSED | mustBeBetween | [0, 30000000] | 201879 | 8.79 ms        |
# | lease_commence_date_column_exists_check | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.93 ms        |
# | month_column_exists_check               | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.25 ms        |
# | month_logical_type_check                | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 9.55 ms        |
# | remaining_lease_column_exists_check     | hdb_resale_prices.remaining_lease     | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.78 ms        |
# | resale_price_column_exists_check        | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.69 ms        |
# | resale_price_must_not_exceed_2m         | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 18.07 ms       |
# | storey_range_column_exists_check        | hdb_resale_prices.storey_range        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.95 ms        |
# | street_name_column_exists_check         | hdb_resale_prices.street_name         | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 3.78 ms        |
# | town_column_exists_check                | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.16 ms        |
# | town_nullValues                         | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 13.75 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# Total Execution:       203.68 ms
# ValidationResult(passed=False, checks=20, passed_checks=16, failed_checks=4)

# %% [markdown]
# <a id="4-filtering-rows"></a>
# ## 4. Filtering Rows Before Validation
#
# Filter conditions let you validate only a subset of your data, useful for incremental validation of new records.
#
# Table name keys in `filter_conditions` support **wildcard patterns** via Python's [`fnmatch`](https://docs.python.org/3/library/fnmatch.html) module:
#
# | Pattern | Matches | Does Not Match |
# |---------|---------|----------------|
# | `"emp*"` | `employees`, `emp_history`, `emp_details` | `department` |
# | `"table?"` | `table1`, `table2` | `table10` |
# | `"[abc]*"` | `accounts`, `billing`, `customers` | `delivery` |
# | `"*_archive"` | `orders_archive`, `customers_archive` | `orders` |
# | `"*"` | All tables (useful for tenant filtering) | -- |
#
# If multiple patterns match a table, all conditions are combined with AND.
#
# The three examples below share one DuckDB connection.

# %%
from vowl.adapters import IbisAdapter, FilterCondition

con = ibis.duckdb.connect()
hdb_df = pd.read_csv(HDB_CSV, low_memory=False).fillna("")
hdb_df["lease_commence_date"] = hdb_df["lease_commence_date"].astype(str)
con.create_table("hdb_resale_prices", hdb_df)

# Dict-style filter: only validate rows from 2024 onwards
adapter = IbisAdapter(
    con,
    filter_conditions={
        "hdb_resale_prices": {
            "field": "month",
            "operator": ">=",
            "value": "2024-01",
        }
    },
)

result = validate_data(contract=str(HDB_CONTRACT), adapter=adapter)

# %%
# Dict-style filter (rows from 2024 onwards)
result.print_summary()
# Out:
# === Data Quality Validation Results ===
#    Contract Version:      v3.1.0
#    Contract ID:           c11443ee-542f-4442-b28d-2d224342be37
#    Schemas:               hdb_resale_prices
#
#  OVERALL DATA QUALITY
#    Overall:
#      Checks Pass Rate:       19 / 20 (95.0%)
#
#    hdb_resale_prices:
#      Overall:
#        Checks Pass Rate:       19 / 20 (95.0%)
#        ERRORED Checks:         0
#      Single Table:
#        Checks Pass Rate:       19 / 20 (95.0%)
#        ERRORED Checks:         0
#        Unique Passed Rows:     32,727 / 32,729 (99.9%)
#      Multi Table:
#        Checks Pass Rate:       0 / 0 (N/A)
#        ERRORED Checks:         0
#        Non-unique Failed Rows: 0
#
#
#  CHECK RESULTS
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | check_id                                | Target                                | tables_in_query   | status | operator      | expected      | actual | execution time |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | floor_area_must_be_less_than_200        | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | FAILED | mustBe        | 0             | 2      | 21.14 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | AddressBlockHouseNumber                 | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 22.78 ms       |
# | Month                                   | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 22.38 ms       |
# | Year                                    | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 22.33 ms       |
# | block_column_exists_check               | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.04 ms        |
# | flat_model_column_exists_check          | hdb_resale_prices.flat_model          | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.51 ms        |
# | flat_type_column_exists_check           | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.01 ms        |
# | flat_type_invalidValues                 | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 24.01 ms       |
# | floor_area_sqm_column_exists_check      | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.22 ms        |
# | hdb_resale_prices_rowCount              | hdb_resale_prices                     | hdb_resale_prices | PASSED | mustBeBetween | [0, 30000000] | 32729  | 11.75 ms       |
# | lease_commence_date_column_exists_check | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 7.86 ms        |
# | month_column_exists_check               | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.91 ms        |
# | month_logical_type_check                | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.93 ms        |
# | remaining_lease_column_exists_check     | hdb_resale_prices.remaining_lease     | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.34 ms        |
# | resale_price_column_exists_check        | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.51 ms        |
# | resale_price_must_not_exceed_2m         | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 16.27 ms       |
# | storey_range_column_exists_check        | hdb_resale_prices.storey_range        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.03 ms        |
# | street_name_column_exists_check         | hdb_resale_prices.street_name         | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.96 ms        |
# | town_column_exists_check                | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 23.55 ms       |
# | town_nullValues                         | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 16.98 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# Total Execution:       264.49 ms
# ValidationResult(passed=False, checks=20, passed_checks=19, failed_checks=1)

# %%
# Multiple filter conditions on the same table (combined with AND)
adapter = IbisAdapter(
    con,
    filter_conditions={
        "hdb_resale_prices": [
            FilterCondition(field="month", operator=">=", value="2024-01"),
            FilterCondition(field="town", operator="=", value="ANG MO KIO"),
        ]
    },
)

result = validate_data(contract=str(HDB_CONTRACT), adapter=adapter)

# %%
# Multiple conditions combined with AND
result.print_summary()
# Out:
# === Data Quality Validation Results ===
#    Contract Version:      v3.1.0
#    Contract ID:           c11443ee-542f-4442-b28d-2d224342be37
#    Schemas:               hdb_resale_prices
#
#  OVERALL DATA QUALITY
#    Overall:
#      Checks Pass Rate:       20 / 20 (100.0%)
#
#    hdb_resale_prices:
#      Overall:
#        Checks Pass Rate:       20 / 20 (100.0%)
#        ERRORED Checks:         0
#      Single Table:
#        Checks Pass Rate:       20 / 20 (100.0%)
#        ERRORED Checks:         0
#        Unique Passed Rows:     1,264 / 1,264 (100.0%)
#      Multi Table:
#        Checks Pass Rate:       0 / 0 (N/A)
#        ERRORED Checks:         0
#        Non-unique Failed Rows: 0
#
#
#  CHECK RESULTS
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | check_id                                | Target                                | tables_in_query   | status | operator      | expected      | actual | execution time |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | AddressBlockHouseNumber                 | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 21.82 ms       |
# | Month                                   | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 21.56 ms       |
# | Year                                    | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 21.78 ms       |
# | block_column_exists_check               | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.17 ms        |
# | flat_model_column_exists_check          | hdb_resale_prices.flat_model          | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 9.00 ms        |
# | flat_type_column_exists_check           | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.15 ms        |
# | flat_type_invalidValues                 | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 23.74 ms       |
# | floor_area_must_be_less_than_200        | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 21.29 ms       |
# | floor_area_sqm_column_exists_check      | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 7.67 ms        |
# | hdb_resale_prices_rowCount              | hdb_resale_prices                     | hdb_resale_prices | PASSED | mustBeBetween | [0, 30000000] | 1264   | 11.68 ms       |
# | lease_commence_date_column_exists_check | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.17 ms        |
# | month_column_exists_check               | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.83 ms        |
# | month_logical_type_check                | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 9.25 ms        |
# | remaining_lease_column_exists_check     | hdb_resale_prices.remaining_lease     | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.70 ms        |
# | resale_price_column_exists_check        | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.65 ms        |
# | resale_price_must_not_exceed_2m         | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 20.64 ms       |
# | storey_range_column_exists_check        | hdb_resale_prices.storey_range        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 8.86 ms        |
# | street_name_column_exists_check         | hdb_resale_prices.street_name         | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.43 ms        |
# | town_column_exists_check                | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 23.61 ms       |
# | town_nullValues                         | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 17.32 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# Total Execution:       269.32 ms
# ValidationResult(passed=True, checks=20, passed_checks=20, failed_checks=0)

# %%
# Wildcard pattern matching on table names
# The "*" pattern applies a filter to ALL tables in the contract
adapter = IbisAdapter(
    con,
    filter_conditions={
        # "*" matches every table name (via fnmatch). Useful for multi-tenant
        # scenarios where every table has a shared column like tenant_id.
        "*": FilterCondition(field="month", operator=">=", value="2020-01"),
    },
)

result = validate_data(contract=str(HDB_CONTRACT), adapter=adapter)

# %%
# Wildcard "*" filter applied to every table
result.print_summary()
# Out:
# === Data Quality Validation Results ===
#    Contract Version:      v3.1.0
#    Contract ID:           c11443ee-542f-4442-b28d-2d224342be37
#    Schemas:               hdb_resale_prices
#
#  OVERALL DATA QUALITY
#    Overall:
#      Checks Pass Rate:       19 / 20 (95.0%)
#
#    hdb_resale_prices:
#      Overall:
#        Checks Pass Rate:       19 / 20 (95.0%)
#        ERRORED Checks:         0
#      Single Table:
#        Checks Pass Rate:       19 / 20 (95.0%)
#        ERRORED Checks:         0
#        Unique Passed Rows:     137,616 / 137,623 (99.9%)
#      Multi Table:
#        Checks Pass Rate:       0 / 0 (N/A)
#        ERRORED Checks:         0
#        Non-unique Failed Rows: 0
#
#
#  CHECK RESULTS
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | check_id                                | Target                                | tables_in_query   | status | operator      | expected      | actual | execution time |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | floor_area_must_be_less_than_200        | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | FAILED | mustBe        | 0             | 7      | 20.50 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | AddressBlockHouseNumber                 | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 23.23 ms       |
# | Month                                   | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 22.68 ms       |
# | Year                                    | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 23.80 ms       |
# | block_column_exists_check               | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.10 ms        |
# | flat_model_column_exists_check          | hdb_resale_prices.flat_model          | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.81 ms        |
# | flat_type_column_exists_check           | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.27 ms        |
# | flat_type_invalidValues                 | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 24.24 ms       |
# | floor_area_sqm_column_exists_check      | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.99 ms        |
# | hdb_resale_prices_rowCount              | hdb_resale_prices                     | hdb_resale_prices | PASSED | mustBeBetween | [0, 30000000] | 137623 | 10.39 ms       |
# | lease_commence_date_column_exists_check | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.86 ms        |
# | month_column_exists_check               | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.61 ms        |
# | month_logical_type_check                | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 9.34 ms        |
# | remaining_lease_column_exists_check     | hdb_resale_prices.remaining_lease     | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.12 ms        |
# | resale_price_column_exists_check        | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 10.71 ms       |
# | resale_price_must_not_exceed_2m         | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 20.41 ms       |
# | storey_range_column_exists_check        | hdb_resale_prices.storey_range        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.05 ms        |
# | street_name_column_exists_check         | hdb_resale_prices.street_name         | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.04 ms        |
# | town_column_exists_check                | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 6.10 ms        |
# | town_nullValues                         | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 16.61 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# Total Execution:       242.84 ms
# ValidationResult(passed=False, checks=20, passed_checks=19, failed_checks=1)

# %% [markdown]
# ---
#
# # Understanding the Results
#
# Every `validate_data(...)` call returns a `ValidationResult`. This section covers the accessors it exposes -- summary DataFrames, failed-row views, and the annotated full table.

# %% [markdown]
# <a id="5-validationresult"></a>
# ## 5. The ValidationResult Object
#
# The `ValidationResult` object provides several ways to inspect and export results. First, run a validation to work with.

# %%
# Run a validation to work with
result = validate_data(contract=str(HDB_CONTRACT), df=pd.read_csv(HDB_CSV, low_memory=False).fillna(""))

# %%
# Check overall pass/fail, then print the summary (without failed rows)
print(f"All checks passed: {result.passed}")
result.print_summary()
# Out:
# All checks passed: False
#
#
# === Data Quality Validation Results ===
#    Contract Version:      v3.1.0
#    Contract ID:           c11443ee-542f-4442-b28d-2d224342be37
#    Schemas:               hdb_resale_prices
#
#  OVERALL DATA QUALITY
#    Overall:
#      Checks Pass Rate:       16 / 20 (80.0%)
#
#    hdb_resale_prices:
#      Overall:
#        Checks Pass Rate:       16 / 20 (80.0%)
#        ERRORED Checks:         0
#      Single Table:
#        Checks Pass Rate:       16 / 20 (80.0%)
#        ERRORED Checks:         0
#        Unique Passed Rows:     201,861 / 201,879 (99.9%)
#      Multi Table:
#        Checks Pass Rate:       0 / 0 (N/A)
#        ERRORED Checks:         0
#        Non-unique Failed Rows: 0
#
#
#  CHECK RESULTS
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | check_id                                | Target                                | tables_in_query   | status | operator      | expected      | actual | execution time |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | AddressBlockHouseNumber                 | hdb_resale_prices.block               | hdb_resale_prices | FAILED | mustBe        | 0             | 1      | 17.83 ms       |
# | Month                                   | hdb_resale_prices.month               | hdb_resale_prices | FAILED | mustBe        | 0             | 2      | 20.55 ms       |
# | Year                                    | hdb_resale_prices.lease_commence_date | hdb_resale_prices | FAILED | mustBe        | 0             | 3      | 17.44 ms       |
# | floor_area_must_be_less_than_200        | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | FAILED | mustBe        | 0             | 12     | 14.03 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# | block_column_exists_check               | hdb_resale_prices.block               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 4.97 ms        |
# | flat_model_column_exists_check          | hdb_resale_prices.flat_model          | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.25 ms        |
# | flat_type_column_exists_check           | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.35 ms        |
# | flat_type_invalidValues                 | hdb_resale_prices.flat_type           | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 22.27 ms       |
# | floor_area_sqm_column_exists_check      | hdb_resale_prices.floor_area_sqm      | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.26 ms        |
# | hdb_resale_prices_rowCount              | hdb_resale_prices                     | hdb_resale_prices | PASSED | mustBeBetween | [0, 30000000] | 201879 | 8.37 ms        |
# | lease_commence_date_column_exists_check | hdb_resale_prices.lease_commence_date | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.39 ms        |
# | month_column_exists_check               | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.55 ms        |
# | month_logical_type_check                | hdb_resale_prices.month               | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 9.06 ms        |
# | remaining_lease_column_exists_check     | hdb_resale_prices.remaining_lease     | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.04 ms        |
# | resale_price_column_exists_check        | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.20 ms        |
# | resale_price_must_not_exceed_2m         | hdb_resale_prices.resale_price        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 14.52 ms       |
# | storey_range_column_exists_check        | hdb_resale_prices.storey_range        | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.19 ms        |
# | street_name_column_exists_check         | hdb_resale_prices.street_name         | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.01 ms        |
# | town_column_exists_check                | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 5.46 ms        |
# | town_nullValues                         | hdb_resale_prices.town                | hdb_resale_prices | PASSED | mustBe        | 0             | 0      | 13.93 ms       |
# +-----------------------------------------+---------------------------------------+-------------------+--------+---------------+---------------+--------+----------------+
# Total Execution:       195.67 ms
# ValidationResult(passed=False, checks=20, passed_checks=16, failed_checks=4)

# %% [markdown]
# ### Check Results DataFrame
#
# `get_check_results_df()` returns a single DataFrame with one row per check: status, expected/actual values, execution time, dimension, and more.

# %%
# Full check results as a DataFrame (one row per check)
check_results_df = result.get_check_results_df()

# To include contract and check definitions in the DataFrame, use:
# check_results_df = result.get_check_results_df(include_contract_definition=True, include_check_definition=True)

# %%
# View the check results
check_results_df.to_pandas()
# Out:
#                                  check_name  \
# 0                 month_column_exists_check
# 1                  month_logical_type_check
# 2                  town_column_exists_check
# 3             flat_type_column_exists_check
# 4                 block_column_exists_check
# 5           street_name_column_exists_check
# 6          storey_range_column_exists_check
# 7        floor_area_sqm_column_exists_check
# 8            flat_model_column_exists_check
# 9   lease_commence_date_column_exists_check
# 10      remaining_lease_column_exists_check
# 11         resale_price_column_exists_check
# 12               hdb_resale_prices_rowCount
# 13                                    Month
# 14                          town_nullValues
# 15                  flat_type_invalidValues
# 16                  AddressBlockHouseNumber
# 17         floor_area_must_be_less_than_200
# 18                                     Year
# 19          resale_price_must_not_exceed_2m
#
#                                    target        schema_name engine  status  \
# 0                 hdb_resale_prices.month  hdb_resale_prices    sql  PASSED
# 1                 hdb_resale_prices.month  hdb_resale_prices    sql  PASSED
# 2                  hdb_resale_prices.town  hdb_resale_prices    sql  PASSED
# 3             hdb_resale_prices.flat_type  hdb_resale_prices    sql  PASSED
# 4                 hdb_resale_prices.block  hdb_resale_prices    sql  PASSED
# 5           hdb_resale_prices.street_name  hdb_resale_prices    sql  PASSED
# 6          hdb_resale_prices.storey_range  hdb_resale_prices    sql  PASSED
# 7        hdb_resale_prices.floor_area_sqm  hdb_resale_prices    sql  PASSED
# 8            hdb_resale_prices.flat_model  hdb_resale_prices    sql  PASSED
# 9   hdb_resale_prices.lease_commence_date  hdb_resale_prices    sql  PASSED
# 10      hdb_resale_prices.remaining_lease  hdb_resale_prices    sql  PASSED
# 11         hdb_resale_prices.resale_price  hdb_resale_prices    sql  PASSED
# 12                      hdb_resale_prices  hdb_resale_prices    sql  PASSED
# 13                hdb_resale_prices.month  hdb_resale_prices    sql  FAILED
# 14                 hdb_resale_prices.town  hdb_resale_prices    sql  PASSED
# 15            hdb_resale_prices.flat_type  hdb_resale_prices    sql  PASSED
# 16                hdb_resale_prices.block  hdb_resale_prices    sql  FAILED
# 17       hdb_resale_prices.floor_area_sqm  hdb_resale_prices    sql  FAILED
# 18  hdb_resale_prices.lease_commence_date  hdb_resale_prices    sql  FAILED
# 19         hdb_resale_prices.resale_price  hdb_resale_prices    sql  PASSED
#
#          operator actual_value expected_value  failed_rows_count  \
# 0          mustBe            0              0                  0
# 1          mustBe            0              0                  0
# 2          mustBe            0              0                  0
# 3          mustBe            0              0                  0
# 4          mustBe            0              0                  0
# 5          mustBe            0              0                  0
# 6          mustBe            0              0                  0
# 7          mustBe            0              0                  0
# 8          mustBe            0              0                  0
# 9          mustBe            0              0                  0
# 10         mustBe            0              0                  0
# 11         mustBe            0              0                  0
# 12  mustBeBetween       201879  [0, 30000000]                  0
# 13         mustBe            2              0                  2
# 14         mustBe            0              0                  0
# 15         mustBe            0              0                  0
# 16         mustBe            1              0                  1
# 17         mustBe           12              0                 12
# 18         mustBe            3              0                  3
# 19         mustBe            0              0                  0
#
#    aggregation_type message  \
# 0             count
# 1             count
# 2             count
# 3             count
# 4             count
# 5             count
# 6             count
# 7             count
# 8             count
# 9             count
# 10            count
# 11            count
# 12            count
# 13            count
# 14            count
# 15            count
# 16            count
# 17            count
# 18            count
# 19            count
#
#                               rendered_implementation        tables_in_query  \
# 0   SELECT COUNT(*) FROM (SELECT "month" FROM "hdb...  ['hdb_resale_prices']
# 1   SELECT COUNT(*) FROM "hdb_resale_prices" WHERE...  ['hdb_resale_prices']
# 2   SELECT COUNT(*) FROM (SELECT "town" FROM "hdb_...  ['hdb_resale_prices']
# 3   SELECT COUNT(*) FROM (SELECT "flat_type" FROM ...  ['hdb_resale_prices']
# 4   SELECT COUNT(*) FROM (SELECT "block" FROM "hdb...  ['hdb_resale_prices']
# 5   SELECT COUNT(*) FROM (SELECT "street_name" FRO...  ['hdb_resale_prices']
# 6   SELECT COUNT(*) FROM (SELECT "storey_range" FR...  ['hdb_resale_prices']
# 7   SELECT COUNT(*) FROM (SELECT "floor_area_sqm" ...  ['hdb_resale_prices']
# 8   SELECT COUNT(*) FROM (SELECT "flat_model" FROM...  ['hdb_resale_prices']
# 9   SELECT COUNT(*) FROM (SELECT "lease_commence_d...  ['hdb_resale_prices']
# 10  SELECT COUNT(*) FROM (SELECT "remaining_lease"...  ['hdb_resale_prices']
# 11  SELECT COUNT(*) FROM (SELECT "resale_price" FR...  ['hdb_resale_prices']
# 12           SELECT COUNT(*) FROM "hdb_resale_prices"  ['hdb_resale_prices']
# 13  SELECT COUNT(*) FROM "hdb_resale_prices" WHERE...  ['hdb_resale_prices']
# 14  SELECT COUNT(*) FROM "hdb_resale_prices" WHERE...  ['hdb_resale_prices']
# 15  SELECT COUNT(*) FROM "hdb_resale_prices" WHERE...  ['hdb_resale_prices']
# 16  SELECT COUNT(*) FROM "hdb_resale_prices" WHERE...  ['hdb_resale_prices']
# 17  SELECT COUNT(*) FROM "hdb_resale_prices" WHERE...  ['hdb_resale_prices']
# 18  SELECT COUNT(*) FROM "hdb_resale_prices" WHERE...  ['hdb_resale_prices']
# 19  SELECT COUNT(*) FROM "hdb_resale_prices" WHERE...  ['hdb_resale_prices']
#
#                                check_path                      check_ref_type  \
# 0          $.schema[0].properties[0].name  DeclaredColumnExistsCheckReference
# 1   $.schema[0].properties[0].logicalType           LogicalTypeCheckReference
# 2          $.schema[0].properties[1].name  DeclaredColumnExistsCheckReference
# 3          $.schema[0].properties[2].name  DeclaredColumnExistsCheckReference
# 4          $.schema[0].properties[3].name  DeclaredColumnExistsCheckReference
# 5          $.schema[0].properties[4].name  DeclaredColumnExistsCheckReference
# 6          $.schema[0].properties[5].name  DeclaredColumnExistsCheckReference
# 7          $.schema[0].properties[6].name  DeclaredColumnExistsCheckReference
# 8          $.schema[0].properties[7].name  DeclaredColumnExistsCheckReference
# 9          $.schema[0].properties[8].name  DeclaredColumnExistsCheckReference
# 10         $.schema[0].properties[9].name  DeclaredColumnExistsCheckReference
# 11        $.schema[0].properties[10].name  DeclaredColumnExistsCheckReference
# 12                 $.schema[0].quality[0]              RowCountCheckReference
# 13   $.schema[0].properties[0].quality[0]             SQLColumnCheckReference
# 14   $.schema[0].properties[1].quality[0]            NullValuesCheckReference
# 15   $.schema[0].properties[2].quality[0]         InvalidValuesCheckReference
# 16   $.schema[0].properties[3].quality[0]             SQLColumnCheckReference
# 17   $.schema[0].properties[6].quality[0]             SQLColumnCheckReference
# 18   $.schema[0].properties[8].quality[0]             SQLColumnCheckReference
# 19  $.schema[0].properties[10].quality[0]             SQLColumnCheckReference
#
#    logical_type is_generated  execution_time_ms
# 0        string         True           5.548125
# 1        string         True           9.062458
# 2           NaN         True           5.457458
# 3           NaN         True           5.345625
# 4           NaN         True           4.971542
# 5           NaN         True           5.014542
# 6           NaN         True           5.188584
# 7           NaN         True           5.263041
# 8           NaN         True           5.245667
# 9           NaN         True           5.387208
# 10          NaN         True           5.040583
# 11          NaN         True           5.200291
# 12          NaN         True           8.371417
# 13       string        False          20.553000
# 14          NaN         True          13.929833
# 15          NaN         True          22.268792
# 16          NaN        False          17.827208
# 17          NaN        False          14.033417
# 18          NaN        False          17.441208
# 19          NaN        False          14.520583

# %% [markdown]
# ### Failed Rows (per check)
#
# `get_output_dfs()` returns a dict of `{check_id: DataFrame}`, one entry per failed check, containing the actual rows that failed.

# %%
# Failed rows grouped by check. Each key is "schema::check_name"
output_dfs = result.get_output_dfs()

# %%
# Display the failed rows for each check
for check_id, failed_df in output_dfs.items():
    if len(failed_df) == 0:
        continue  # Skip checks with no failed rows
    print(f"\n{'='*60}")
    print(f"Check: {check_id}  ({len(failed_df)} failed rows)")
    print(f"{'='*60}")
    display(failed_df.to_pandas().head())
# Out:
# ============================================================
# Check: hdb_resale_prices::AddressBlockHouseNumber  (1 failed rows)
# ============================================================
#      month   town flat_type block         street_name storey_range  \
# 0  2017-01  BEDOK    4 ROOM        BEDOK RESERVOIR RD     07 TO 09
#
#    floor_area_sqm  flat_model lease_commence_date     remaining_lease  \
# 0            84.0  Simplified                1986  68 years 10 months
#
#    resale_price                 check_id    tables_in_query
# 0      395000.0  AddressBlockHouseNumber  hdb_resale_prices
# ============================================================
# Check: hdb_resale_prices::Month  (2 failed rows)
# ============================================================
#       month    town flat_type block   street_name storey_range  \
# 0  2017-jan   BEDOK    5 ROOM    21  CHAI CHEE RD     07 TO 09
# 1  2017-jan  BISHAN    3 ROOM   105  BISHAN ST 12     04 TO 06
#
#    floor_area_sqm     flat_model lease_commence_date     remaining_lease  \
# 0           130.0  Adjoined flat                1972  54 years 06 months
# 1             4.0     Simplified                1985  67 years 11 months
#
#    resale_price check_id    tables_in_query
# 0      530000.0    Month  hdb_resale_prices
# 1      395000.0    Month  hdb_resale_prices
# ============================================================
# Check: hdb_resale_prices::Year  (3 failed rows)
# ============================================================
#      month        town flat_type block       street_name storey_range  \
# 0  2017-01  ANG MO KIO    3 ROOM   219  ANG MO KIO AVE 1     07 TO 09
# 1  2017-01  ANG MO KIO    3 ROOM   211  ANG MO KIO AVE 3     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   330  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm      flat_model lease_commence_date     remaining_lease  \
# 0            67.0  New Generation              1977.0  59 years 06 months
# 1            67.0  New Generation                 abc  59 years 03 months
# 2            68.0  New Generation                                63 years
#
#    resale_price check_id    tables_in_query
# 0      297000.0     Year  hdb_resale_prices
# 1      325000.0     Year  hdb_resale_prices
# 2      338000.0     Year  hdb_resale_prices
# ============================================================
# Check: hdb_resale_prices::floor_area_must_be_less_than_200  (12 failed rows)
# ============================================================
#      month             town  flat_type block          street_name  \
# 0  2017-06  KALLANG/WHAMPOA     3 ROOM    38          JLN BAHAGIA
# 1  2017-09    CHOA CHU KANG  EXECUTIVE   641  CHOA CHU KANG ST 64
# 2  2017-12  KALLANG/WHAMPOA     3 ROOM    65           JLN MA'MOR
# 3  2018-01    CHOA CHU KANG  EXECUTIVE   639  CHOA CHU KANG ST 64
# 4  2018-09  KALLANG/WHAMPOA     3 ROOM    41          JLN BAHAGIA
#
#   storey_range  floor_area_sqm          flat_model lease_commence_date  \
# 0     01 TO 03           215.0             Terrace                1972
# 1     16 TO 18           215.0  Premium Maisonette                1998
# 2     01 TO 03           249.0             Terrace                1972
# 3     10 TO 12           215.0  Premium Maisonette                1998
# 4     01 TO 03           237.0             Terrace                1972
#
#       remaining_lease  resale_price                          check_id  \
# 0   54 years 01 month      830000.0  floor_area_must_be_less_than_200
# 1  79 years 04 months      888000.0  floor_area_must_be_less_than_200
# 2  53 years 07 months     1053888.0  floor_area_must_be_less_than_200
# 3            79 years      900000.0  floor_area_must_be_less_than_200
# 4  52 years 10 months     1185000.0  floor_area_must_be_less_than_200
#
#      tables_in_query
# 0  hdb_resale_prices
# 1  hdb_resale_prices
# 2  hdb_resale_prices
# 3  hdb_resale_prices
# 4  hdb_resale_prices

# %% [markdown]
# ### Consolidated Failed Rows (per table)
#
# `get_consolidated_output_dfs()` deduplicates failed rows across all checks and groups them by table. Useful when multiple checks flag the same row.

# %%
# Consolidated: deduplicated failed rows grouped by table
consolidated = result.get_consolidated_output_dfs()

# %%
# Display the deduplicated failed rows per table
for table_name, consolidated_df in consolidated.items():
    print(f"\n{'='*60}")
    print(f"Table: {table_name}  ({len(consolidated_df)} unique failed rows)")
    print(f"{'='*60}")
    display(consolidated_df.to_pandas().head())
# Out:
# ============================================================
# Table: hdb_resale_prices  (18 unique failed rows)
# ============================================================
#       month        town flat_type block         street_name storey_range  \
# 0   2017-01       BEDOK    4 ROOM        BEDOK RESERVOIR RD     07 TO 09
# 1  2017-jan       BEDOK    5 ROOM    21        CHAI CHEE RD     07 TO 09
# 2  2017-jan      BISHAN    3 ROOM   105        BISHAN ST 12     04 TO 06
# 3   2017-01  ANG MO KIO    3 ROOM   219    ANG MO KIO AVE 1     07 TO 09
# 4   2017-01  ANG MO KIO    3 ROOM   211    ANG MO KIO AVE 3     01 TO 03
#
#    floor_area_sqm      flat_model lease_commence_date     remaining_lease  \
# 0            84.0      Simplified                1986  68 years 10 months
# 1           130.0   Adjoined flat                1972  54 years 06 months
# 2             4.0      Simplified                1985  67 years 11 months
# 3            67.0  New Generation              1977.0  59 years 06 months
# 4            67.0  New Generation                 abc  59 years 03 months
#
#    resale_price                check_ids    tables_in_query
# 0      395000.0  AddressBlockHouseNumber  hdb_resale_prices
# 1      530000.0                    Month  hdb_resale_prices
# 2      395000.0                    Month  hdb_resale_prices
# 3      297000.0                     Year  hdb_resale_prices
# 4      325000.0                     Year  hdb_resale_prices

# %% [markdown]
# ### Saving to Disk
#
# `result.save(...)` writes the results (CSVs + a JSON summary) to a directory.

# %%
# Save results to disk (CSV + JSON summary)
result.save(output_dir="outputs", prefix="vowl_demo_HDB_results")
# Out:
# Results saved:
#    - outputs/vowl_demo_HDB_results_check_results.csv
#    - outputs/vowl_demo_HDB_results_hdb_resale_prices.csv
#    - outputs/vowl_demo_HDB_results_summary.json
# ValidationResult(passed=False, checks=20, passed_checks=16, failed_checks=4)

# %% [markdown]
# <a id="6-annotated-output"></a>
# ## 6. Annotated Output — Your Full Table, Flagged
#
# The main accessor here is **`get_annotated_output()`**. It returns your full table with one extra column, `check_info`, so you can see failures in the context of every row instead of on their own.
#
# It returns a dict with two keys:
#
# - **`"annotated"`** — `{schema: table}`. Each table is your full data plus a `check_info` column. Every original row is kept. `check_info` is `null` for rows that passed every check, and a list of the failing check(s) for rows that didn't.
# - **`"residues"`** — failed rows for checks that can't be attached to a single table (cross-table, aggregation, and column-subset checks). The single-table HDB contract below has none; the [residual-rows example](#residual-rows) at the end of this section shows them using a multi-source contract.
#
# > Not every check can be merged into the annotated table. For the full rules and worked examples, see [Known Issues: Annotated Output](../../docs/known-issues.md#annotated-output-not-all-checks-can-be-merged).

# %% [markdown]
# ### Choosing How Much Detail: the `check_info` Options
#
# `check_info` is a **list of objects, one per failing check** (stored as a JSON string in the column). The `check_info=` argument sets how many fields each object carries:
#
# | `check_info` | Each object contains | Use it when |
# |---|---|---|
# | `"names"` *(default)* | `check_name` | You only need to know *which* checks a row failed |
# | `"summary"` | `check_name`, `dimension`, `tags`, `target` | You want each failure's quality dimension, tags, and column — e.g. to split completeness vs. accuracy |
# | `"full"` | the entire check definition (`type`, `description`, `query`, `mustBe`, `dimension`, `tags`) plus `check_name` and `target` | You want everything, including the underlying rule/SQL, on every row |
#
# All three return the **same shape** — a list of objects — so you always read a value the same way (`json.loads(cell)[0]["check_name"]`); they differ only in how many fields each object has. A row failing two checks gets a two-object list.
#
# ```text
# "names"    [{"check_name": "Month"}]
# "summary"  [{"check_name": "Month", "dimension": "conformity",
#              "tags": ["SG-DRM v5.0"], "target": "hdb_resale_prices.month"}]
# "full"     [{"type": "sql", "name": "Month", "description": "...", "mustBe": 0,
#              "query": "SELECT COUNT(*) ...", "tags": ["SG-DRM v5.0"],
#              "dimension": "conformity", "check_name": "Month",
#              "target": "hdb_resale_prices.month"}]
# ```
#
# The examples below use `"summary"`.

# %%
# "annotated" -> {schema: your full table + a check_info column}
# "residues"  -> failed rows for checks that can't attach to one table (shown later)
# check_info="summary" -> each object also carries dimension, tags, and target.
output = result.get_annotated_output(check_info="summary")
annotated = output["annotated"]["hdb_resale_prices"].to_pandas()

# %%
# Inspect the structure of the annotated output
print("Top-level keys:    ", list(output.keys()))
print("Annotated schemas: ", list(output["annotated"].keys()))
print("Residue keys:      ", list(output["residues"].keys()))
print(f"\nAnnotated table: {annotated.shape[0]:,} rows x {annotated.shape[1]} columns")
print("Columns:", list(annotated.columns))
# Out:
# Top-level keys:     ['annotated', 'residues']
# Annotated schemas:  ['hdb_resale_prices']
# Residue keys:       []
#
# Annotated table: 201,879 rows x 12 columns
# Columns: ['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range', 'floor_area_sqm', 'flat_model', 'lease_commence_date', 'remaining_lease', 'resale_price', 'check_info']

# %% [markdown]
# ### Inspecting the Full Table, Flagged Rows First
#
# Every original row is present. `check_info` is `null` for rows that passed and a JSON list for rows that failed — one object per failing check (here carrying `dimension`, `tags`, and `target` from the `"summary"` preset). Sorting by `check_info` (nulls last) floats the flagged rows to the top while still showing the whole table.

# %%
# Sort the full table so flagged rows surface first; passing rows (check_info = null) sink.
flagged_first = annotated.sort_values("check_info", na_position="last").reset_index(drop=True)
n_flagged = annotated["check_info"].notna().sum()

# %%
print(f"{n_flagged} flagged rows at the top, {len(annotated) - n_flagged:,} passing rows below\n")
flagged_first[["month", "town", "block", "floor_area_sqm",
               "lease_commence_date", "check_info"]].head(20)
# Out:
# 18 flagged rows at the top, 201,861 passing rows below
#        month             town block  floor_area_sqm lease_commence_date  \
# 0    2017-01            BEDOK                  84.0                1986
# 1   2017-jan            BEDOK    21           130.0                1972
# 2   2017-jan           BISHAN   105             4.0                1985
# 3    2017-01       ANG MO KIO   219            67.0              1977.0
# 4    2017-01       ANG MO KIO   211            67.0                 abc
# 5    2017-01       ANG MO KIO   330            68.0
# 6    2017-06  KALLANG/WHAMPOA    38           215.0                1972
# 7    2017-09    CHOA CHU KANG   641           215.0                1998
# 8    2017-12  KALLANG/WHAMPOA    65           249.0                1972
# 9    2018-01    CHOA CHU KANG   639           215.0                1998
# 10   2018-09  KALLANG/WHAMPOA    41           237.0                1972
# 11   2021-03           BISHAN   446           243.0                1990
# 12   2021-04           BISHAN   454           243.0                1989
# 13   2021-04  KALLANG/WHAMPOA    61           222.0                1972
# 14   2021-06  KALLANG/WHAMPOA    39           210.0                1972
# 15   2021-09  KALLANG/WHAMPOA    46           241.0                1972
# 16   2024-02  KALLANG/WHAMPOA    58           208.0                1972
# 17   2024-07  KALLANG/WHAMPOA    53           366.7                1972
# 18   2017-01       ANG MO KIO   406            44.0                1979
# 19   2017-01       ANG MO KIO   108            67.0                1978
#
#                                            check_info
# 0   [{"check_name": "AddressBlockHouseNumber", "di...
# 1   [{"check_name": "Month", "dimension": "conform...
# 2   [{"check_name": "Month", "dimension": "conform...
# 3   [{"check_name": "Year", "dimension": "conformi...
# 4   [{"check_name": "Year", "dimension": "conformi...
# 5   [{"check_name": "Year", "dimension": "conformi...
# 6   [{"check_name": "floor_area_must_be_less_than_...
# 7   [{"check_name": "floor_area_must_be_less_than_...
# 8   [{"check_name": "floor_area_must_be_less_than_...
# 9   [{"check_name": "floor_area_must_be_less_than_...
# 10  [{"check_name": "floor_area_must_be_less_than_...
# 11  [{"check_name": "floor_area_must_be_less_than_...
# 12  [{"check_name": "floor_area_must_be_less_than_...
# 13  [{"check_name": "floor_area_must_be_less_than_...
# 14  [{"check_name": "floor_area_must_be_less_than_...
# 15  [{"check_name": "floor_area_must_be_less_than_...
# 16  [{"check_name": "floor_area_must_be_less_than_...
# 17  [{"check_name": "floor_area_must_be_less_than_...
# 18                                                NaN
# 19                                                NaN

# %% [markdown]
# ### Keeping the Clean Rows for Downstream Use
#
# Because the annotation lives on the full table, separating the good rows from the bad is a one-liner. Filter to where `check_info` is null, drop the annotation column, and you have a clean dataset ready to feed downstream -- no separate join back to the source needed.

# %%
# Keep only the rows that passed every check, then drop the annotation column
clean = annotated[annotated["check_info"].isna()].drop(columns=["check_info"])

# %%
print(f"Clean rows ready for downstream use: {len(clean):,} of {len(annotated):,}")
clean.head()
# Out:
# Clean rows ready for downstream use: 201,861 of 201,879
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model lease_commence_date     remaining_lease  \
# 0            44.0        Improved                1979  61 years 04 months
# 1            67.0  New Generation                1978  60 years 07 months
# 2            67.0  New Generation                1980  62 years 05 months
# 3            68.0  New Generation                1980   62 years 01 month
# 4            67.0  New Generation                1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %% [markdown]
# <a id="residual-rows"></a>
# ### Residual (Non-Mergeable) Rows
#
# The HDB examples above are single-table, so `residues` is empty. Residues appear when a check can't be attached to one table — **aggregation** checks, **column-subset** checks, and **cross-table** checks whose failed rows carry columns from more than the anchor table.
#
# Residues are **per-check**: `get_annotated_output()` returns one entry for each non-mergeable check, keyed `"<schema>::<check_name>"`. They are never grouped together, so a row that fails two such checks appears once under each check's entry. Each entry carries the failed rows plus the same `check_info` column the annotated tables use (a single-element JSON array, shaped by the `check_info` preset) and `tables_in_query` — so everything `get_annotated_output()` returns is read the same way.
#
# > **A cross-table check can *merge* instead of becoming a residue.** If you shape its failed-rows query to project only the anchor table's columns (e.g. `SELECT payroll.*` inside a subquery), the orphan rows match that schema and land directly in its `check_info` column — no residue. The Employee contract below carries both shapes: `orphan_payroll_rows_merge_onto_payroll` (subquery-projected → merges onto `demo_employee_payroll`) and `employee_id_exists_in_master_list` / `phone_number_exists_in_master_list` (bare JOINs → stay residues). See [Known Issues: Annotated Output](../../docs/known-issues.md#annotated-output-not-all-checks-can-be-merged) for the rules.
#
# Below is a quick multi-source run on the Employee dataset, whose contract has cross-table checks. (Multi-source validation is covered in the [Multiple Sources notebook](../2_multiple_sources/multiple_sources.ipynb); we borrow it here just to produce residues.)

# %%
import ibis
from vowl.adapters import IbisAdapter

# Load the two Employee tables onto one DuckDB connection (cross-table contract)
con = ibis.duckdb.connect()
con.create_table("demo_employee_payroll", pd.read_csv(EMPLOYEE_PAYROLL_CSV))
con.create_table("demo_employee_list", pd.read_csv(EMPLOYEE_LIST_CSV))

mt_result = validate_data(contract=str(EMPLOYEE_CONTRACT), adapter=IbisAdapter(con))
mt_output = mt_result.get_annotated_output()

# %%
# Each residue is the failed rows for ONE non-mergeable check, keyed "<schema>::<check>"
print("Annotated schemas:", list(mt_output["annotated"].keys()))
print("Residue keys:     ", list(mt_output["residues"].keys()))

for key, residue in mt_output["residues"].items():
    residue_df = residue.to_pandas()
    print(f"\nResidue '{key}': {len(residue_df)} failed row(s)")
    display(residue_df[["employee_id", "payroll_id", "month",
                        "check_info", "tables_in_query"]])
# Out:
# Annotated schemas: ['demo_employee_payroll', 'demo_employee_list']
# Residue keys:      ['demo_employee_payroll::employee_id_exists_in_master_list', 'demo_employee_payroll::phone_number_exists_in_master_list']
#
# Residue 'demo_employee_payroll::employee_id_exists_in_master_list': 1 failed row(s)
#   employee_id                            payroll_id    month  \
# 0     e939123  e52e556f-79b0-471f-ad08-e27b2c524ace  2025-12
#
#                                           check_info  \
# 0  [{"check_name": "employee_id_exists_in_master_...
#
#                              tables_in_query
# 0  demo_employee_list, demo_employee_payroll
# Residue 'demo_employee_payroll::phone_number_exists_in_master_list': 2 failed row(s)
#   employee_id                            payroll_id    month  \
# 0     e128903  cb04c5bb-9386-44cf-a565-2276744c9cc0  2025-12
# 1     e939123  e52e556f-79b0-471f-ad08-e27b2c524ace  2025-12
#
#                                           check_info  \
# 0  [{"check_name": "phone_number_exists_in_master...
# 1  [{"check_name": "phone_number_exists_in_master...
#
#                              tables_in_query
# 0  demo_employee_list, demo_employee_payroll
# 1  demo_employee_list, demo_employee_payroll

# %% [markdown]
# #### The Other Side: a Cross-Table Check That *Merges*
#
# Whether a check merges is decided by **the columns its failed rows come back with** — they have to match the anchor table's columns exactly. To see why the two cross-table checks above became residues but a third one won't, you need to know how vowl turns the one query you write into the rows it fetches.
#
# **Every check derives two queries from the single query you author:**
#
# 1. a **scalar query** — the `SELECT COUNT(*)` that decides pass/fail, and
# 2. a **failed-rows query** — which vowl builds by rewriting your `COUNT(*)` into `SELECT *`, run lazily only when the check fails and its rows are requested.
#
# The merge is judged entirely on what that *failed-rows* query returns. Crucially, the `COUNT(*)` → `SELECT *` rewrite only swaps the **outer** select list — it never rewrites a subquery's projection.
#
# **Bare JOIN → residue.** The two checks above are written `SELECT COUNT(*) FROM payroll LEFT JOIN ref …`. The rewrite makes that `SELECT * FROM payroll LEFT JOIN ref …`, which returns columns from *both* tables (`ref.*`, all NULL for orphans). That column set doesn't match `demo_employee_payroll`, so the rows can't be placed on any single table → residue.
#
# **Subquery-projected → merges.** The contract also has `orphan_payroll_rows_merge_onto_payroll` — the *same* referential question, but wrapped so the inner query projects only the payroll columns:
#
# ```sql
# SELECT COUNT(*) FROM (
#     SELECT payroll.*                       -- only payroll's columns
#     FROM demo_employee_payroll payroll
#     LEFT JOIN demo_employee_list ref ON payroll.employee_id = ref.employee_id
#     WHERE ref.employee_id IS NULL
# ) AS orphaned_payroll
# ```
#
# Because the rewrite only touches the outer list, the failed-rows query becomes `SELECT * FROM (SELECT payroll.* …)` — the inner `SELECT payroll.*` still governs the shape, so the rows come back with **exactly the payroll columns**. They match `demo_employee_payroll`, so instead of a residue they are annotated **directly onto the payroll table's `check_info` column**. Notice this check is absent from the residue keys above.

# %%
# The subquery-projected cross-table check lands on the payroll annotated table,
# not in residues. Find the payroll rows it flagged.
payroll_annotated = mt_output["annotated"]["demo_employee_payroll"].to_pandas()

MERGED_CHECK = "orphan_payroll_rows_merge_onto_payroll"
flagged = payroll_annotated[
    payroll_annotated["check_info"].fillna("").str.contains(MERGED_CHECK)
]

print(f"'{MERGED_CHECK}' in residues? "
      f"{any(MERGED_CHECK in k for k in mt_output['residues'])}")
print(f"Payroll rows it annotated: {len(flagged)}\n")
display(flagged[["employee_id", "month", "check_info"]])
# Out:
# 'orphan_payroll_rows_merge_onto_payroll' in residues? False
# Payroll rows it annotated: 1
#   employee_id    month                                         check_info
# 2     e939123  2025-12  [{"check_name": "phone_number_logical_type_opt...

# %% [markdown]
# ### Writing Annotated Tables to Disk
#
# `result.save(...)` can write the annotated tables instead of (or alongside) the failed-rows CSVs. The `output_mode` argument controls the layout (every mode also writes `<prefix>_check_results.csv` and `<prefix>_summary.json`):
#
# | Mode | Files written |
# |------|----------------|
# | `"failed_rows"` (default) | One grouped failed-rows CSV per table key, e.g. `<prefix>_<table>.csv` |
# | `"annotated"` | One `<prefix>_<schema>_annotated.csv` per schema (full table + `check_info`), **plus** one `<prefix>_<schema>_<check>_residue.csv` per non-mergeable check |
# | `"both"` | The failed-rows CSVs **and** the annotated CSVs (residues are already covered by the grouped failed-rows CSVs, so no separate `_residue` files are written) |
#
# The `check_info` argument (`"names"` / `"summary"` / `"full"`, described above) sets how much detail the saved `check_info` column carries. To make annotated output the default for every `save()`, pass `ValidationConfig(output_mode="annotated", annotated_check_info="summary")` to `validate_data(config=...)`.
#
# Single-table contracts (like the HDB example) have no non-mergeable checks, so they never produce `_residue` files. The multi-source run below does — let's save it to see them.

# %%
# Write the annotated table(s) to disk
result.save(output_dir="outputs", prefix="vowl_demo_annotated", output_mode="annotated")
# Out:
# Results saved:
#    - outputs/vowl_demo_annotated_check_results.csv
#    - outputs/vowl_demo_annotated_hdb_resale_prices_annotated.csv
#    - outputs/vowl_demo_annotated_summary.json
# ValidationResult(passed=False, checks=20, passed_checks=16, failed_checks=4)

# %% [markdown]
# #### Saving a Run That Has Residues
#
# `result` above is single-table, so its `save(output_mode="annotated")` wrote only `*_annotated.csv` files. Saving the multi-source `mt_result` from the residue example instead also writes one `*_residue.csv` per non-mergeable check — keyed `<schema>_<check>` (the `::` in the residue key becomes `_`). Each residue CSV carries that one check's failed rows plus the same `check_info` column as the annotated tables and `tables_in_query`.

# %%
import os

# Save the multi-source run; annotated mode emits residue CSVs for the
# cross-table checks that can't be merged onto a single table.
mt_result.save(output_dir="outputs", prefix="vowl_demo_residues", output_mode="annotated")

print("\nFiles written:")
for fname in sorted(f for f in os.listdir("outputs") if f.startswith("vowl_demo_residues")):
    tag = "  <- residue" if fname.endswith("_residue.csv") else ""
    print(f"   {fname}{tag}")
# Out:
# Results saved:
#    - outputs/vowl_demo_residues_check_results.csv
#    - outputs/vowl_demo_residues_demo_employee_payroll_annotated.csv
#    - outputs/vowl_demo_residues_demo_employee_list_annotated.csv
#    - outputs/vowl_demo_residues_demo_employee_payroll_employee_id_exists_in_master_list_residue.csv
#    - outputs/vowl_demo_residues_demo_employee_payroll_phone_number_exists_in_master_list_residue.csv
#    - outputs/vowl_demo_residues_summary.json
#
# Files written:
#    vowl_demo_residues_check_results.csv
#    vowl_demo_residues_demo_employee_list_annotated.csv
#    vowl_demo_residues_demo_employee_payroll_annotated.csv
#    vowl_demo_residues_demo_employee_payroll_employee_id_exists_in_master_list_residue.csv  <- residue
#    vowl_demo_residues_demo_employee_payroll_phone_number_exists_in_master_list_residue.csv  <- residue
#    vowl_demo_residues_summary.json

# %% [markdown]
# ### Where the Full Check Definitions Live
#
# To keep the annotated table readable, you'll usually pick `"names"` or `"summary"` rather than `"full"`. You don't lose anything: the complete definition of **every** check — its `dimension`, `tags`, `description`, `query`, and more — is always written to the `*_summary.json` file that `save()` produces, keyed by check name. Keep the table light, and look up the rest here when you need it.

# %%
import json

# save(prefix="vowl_demo_annotated", ...) wrote this alongside the CSVs.
with open("outputs/vowl_demo_annotated_summary.json") as f:
    summary = json.load(f)

# Every check's resolved definition lives under "check_results", keyed by name.
month_check = next(c for c in summary["check_results"] if c["name"] == "Month")

print("Target:    ", month_check["target"])
print("Dimension: ", month_check["check_definition"]["dimension"])
print("Tags:      ", month_check["check_definition"]["tags"])
print("\nFull check_definition:")
print(json.dumps(month_check["check_definition"], indent=2))
# Out:
# Target:     hdb_resale_prices.month
# Dimension:  conformity
# Tags:       ['SG-DRM v5.0']
#
# Full check_definition:
# {
#   "type": "sql",
#   "name": "Month",
#   "description": "Based on ISO 8601, assumed to be in UTC +8 | YYYY-MM",
#   "mustBe": 0,
#   "query": "SELECT COUNT(*)\nFROM \"hdb_resale_prices\"\nWHERE CAST(month AS TEXT) !~ '^[0-9]{4}-(0[1-9]|1[0-2])$';",
#   "tags": [
#     "SG-DRM v5.0"
#   ],
#   "dimension": "conformity"
# }
